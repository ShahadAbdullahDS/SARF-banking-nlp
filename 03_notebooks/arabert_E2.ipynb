# %% [markdown]
# # SARF AraBERT — E2
#
# **Owner:** A
# **Condition:** E2
# **CPT assignment:** general_6k_final_v2.csv (6,000 rows).
#
# CPT on the approved 6K general Saudi-style corpus, then identical MSA fine-tuning.
#
# This notebook contains no model-training implementation. It invokes the one shared `arabert_pipeline.py`, which reads the one shared AraBERT config and the one global 77-label mapping from the project Drive. The held-out Saudi test is not loaded in this notebook.

# %% [markdown]
# ## 1. Install the fixed environment
#
# Choose a GPU runtime before running this cell. If Colab asks to restart after installation, restart the runtime, then rerun this cell and the following cells in order.

# %%
# %pip install --upgrade --prefer-binary "tokenizers==0.21.4" "transformers==4.48.3" "accelerate==1.2.1" "datasets==3.2.0" "scikit-learn==1.6.1" "sentencepiece>=0.2.1"
# %pip install --upgrade "PyArabic==0.6.15" "farasapy==0.1.1" "emoji==1.4.2"
# %pip install --upgrade --no-deps "arabert==1.0.1"
# Out:
# Requirement already satisfied: tokenizers==0.21.4 in /usr/local/lib/python3.13/dist-packages (0.21.4)
# Requirement already satisfied: transformers==4.48.3 in /usr/local/lib/python3.13/dist-packages (4.48.3)
# Requirement already satisfied: accelerate==1.2.1 in /usr/local/lib/python3.13/dist-packages (1.2.1)
# Requirement already satisfied: datasets==3.2.0 in /usr/local/lib/python3.13/dist-packages (3.2.0)
# Requirement already satisfied: scikit-learn==1.6.1 in /usr/local/lib/python3.13/dist-packages (1.6.1)
# Requirement already satisfied: sentencepiece>=0.2.1 in /usr/local/lib/python3.13/dist-packages (0.2.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.13/dist-packages (from tokenizers==0.21.4) (0.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from transformers==4.48.3) (3.32.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.13/dist-packages (from transformers==4.48.3) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from transformers==4.48.3) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from transformers==4.48.3) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.13/dist-packages (from transformers==4.48.3) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from transformers==4.48.3) (2.32.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.13/dist-packages (from transformers==4.48.3) (0.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.13/dist-packages (from transformers==4.48.3) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from accelerate==1.2.1) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.13/dist-packages (from accelerate==1.2.1) (2.11.0+cu128)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets==3.2.0) (23.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets==3.2.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets==3.2.0) (2.2.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets==3.2.0) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.13/dist-packages (from datasets==3.2.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets==3.2.0) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.13/dist-packages (from datasets==3.2.0) (3.14.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn==1.6.1) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn==1.6.1) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn==1.6.1) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==3.2.0) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==3.2.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==3.2.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==3.2.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==3.2.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==3.2.0) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==3.2.0) (1.24.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers==0.21.4) (1.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers==0.21.4) (4.16.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn==1.6.1) (3.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->transformers==4.48.3) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->transformers==4.48.3) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->transformers==4.48.3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->transformers==4.48.3) (2026.7.22)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.10.0->accelerate==1.2.1) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.10.0->accelerate==1.2.1) (12.8.90)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets==3.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets==3.2.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets==3.2.0) (2026.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.10.0->accelerate==1.2.1) (1.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==3.2.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.10.0->accelerate==1.2.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=1.10.0->accelerate==1.2.1) (3.0.3)
# Requirement already satisfied: PyArabic==0.6.15 in /usr/local/lib/python3.13/dist-packages (0.6.15)
# Requirement already satisfied: farasapy==0.1.1 in /usr/local/lib/python3.13/dist-packages (0.1.1)
# Requirement already satisfied: emoji==1.4.2 in /usr/local/lib/python3.13/dist-packages (1.4.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.13/dist-packages (from PyArabic==0.6.15) (1.17.0)
# Requirement already satisfied: requests~=2.32 in /usr/local/lib/python3.13/dist-packages (from farasapy==0.1.1) (2.32.4)
# Requirement already satisfied: tqdm~=4.66 in /usr/local/lib/python3.13/dist-packages (from farasapy==0.1.1) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests~=2.32->farasapy==0.1.1) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests~=2.32->farasapy==0.1.1) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests~=2.32->farasapy==0.1.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests~=2.32->farasapy==0.1.1) (2026.7.22)
# Requirement already satisfied: arabert==1.0.1 in /usr/local/lib/python3.13/dist-packages (1.0.1)

# %% [markdown]
# ## 2. Mount Drive and verify the shared AraBERT source
#
# The project Drive must contain exactly one shared pipeline, config, and label mapping. This cell does not load training data, CPT data, or the held-out test.

# %%
from google.colab import drive
from pathlib import Path
import json
import torch

drive.mount("/content/drive", force_remount=False)

PROJECT_ROOT = Path("/content/drive/MyDrive/SARF_BANKING_NLP_PROJECT")
PIPELINE_PATH = PROJECT_ROOT / "src_04" / "arabert_pipeline.py"
CONFIG_PATH = PROJECT_ROOT / "02_configs" / "arabert_config.json"
MAPPING_PATH = PROJECT_ROOT / "02_configs" / "arabert_label_mapping.json"

assert torch.cuda.is_available(), "GPU required; do not run AraBERT training on CPU."
assert PROJECT_ROOT.is_dir(), f"Project folder not found: {PROJECT_ROOT}"
assert PIPELINE_PATH.is_file(), f"Pipeline not found: {PIPELINE_PATH}"
assert CONFIG_PATH.is_file(), f"Config not found: {CONFIG_PATH}"
assert MAPPING_PATH.is_file(), f"Mapping not found: {MAPPING_PATH}"

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
mapping = json.loads(MAPPING_PATH.read_text(encoding="utf-8"))

assert config["owner"] == "A"
assert config["official_conditions"] == ["E0", "E1", "E2", "E3", "EB"]
assert config["official_seeds"] == [42, 123, 2026]
assert mapping["owner"] == "A"
assert mapping["num_labels"] == 77
assert len(mapping["label_to_id"]) == 77

print({
    "status": "shared AraBERT source verified",
    "owner": config["owner"],
    "condition": "E2",
    "gpu": torch.cuda.get_device_name(0),
    "pipeline": str(PIPELINE_PATH),
    "config": str(CONFIG_PATH),
    "mapping": str(MAPPING_PATH),
    "official_seeds": config["official_seeds"],
    "num_labels": mapping["num_labels"],
    "cpt_assignment": config["conditions"]["E2"],
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'status': 'shared AraBERT source verified', 'owner': 'A', 'condition': 'E2', 'gpu': 'Tesla T4', 'pipeline': '/content/drive/MyDrive/SARF_BANKING_NLP_PROJECT/src_04/arabert_pipeline.py', 'config': '/content/drive/MyDrive/SARF_BANKING_NLP_PROJECT/02_configs/arabert_config.json', 'mapping': '/content/drive/MyDrive/SARF_BANKING_NLP_PROJECT/02_configs/arabert_label_mapping.json', 'official_seeds': [42, 123, 2026], 'num_labels': 77, 'cpt_assignment': {'description': 'CPT on 6K general Saudi-style text, then identical MSA fine-tuning.', 'cpt_enabled': True, 'cpt': {'corpus_directory_relative_path': '03_synthetic_data/05_final_corpora', 'manifest_relative_path': '03_synthetic_data/06_final_audit/corpus_manifest_v2.json', 'corpus_files': ['general_6k_final_v2.csv'], 'corpus_file_rows': [6000], 'total_rows': 6000}}}

# %% [markdown]
# ## 3. Run E2 one seed at a time
#
# Run only one seed per execution. The approved sequence within this condition is `42`, then `123`, then `2026`. The shared pipeline creates outputs directly under `05_runs/arabert/E2/seed_<seed>` and `06_models_and_checkpoints/arabert/E2/seed_<seed>`, refusing to overwrite a completed run.

# %%
SEED = 42
assert SEED in [42, 123, 2026]

# !python "{PIPELINE_PATH}" --project-root "{PROJECT_ROOT}" --condition "E2" --seed {SEED}
# Out:
# 2026-09-12 07:45:27.636192: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-09-12 07:45:33,597 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# Map: 100% 10732/10732 [00:00<00:00, 10767.34 examples/s]
# Map: 100% 1229/1229 [00:00<00:00, 11980.69 examples/s]
# Tokenizing approved E2 CPT corpus: 100% 6000/6000 [00:00<00:00, 12872.97 examples/s]
# BertForMaskedLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Some weights of the model checkpoint at aubmindlab/bert-base-arabertv2 were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /content/drive/MyDrive/SARF_BANKING_NLP_PROJECT/src_04/arabert_pipeline.py:437: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# {'loss': 4.6315, 'grad_norm': 28.03924560546875, 'learning_rate': 4.353333333333334e-05, 'epoch': 0.13}
# {'loss': 4.2124, 'grad_norm': 22.63629722595215, 'learning_rate': 3.6866666666666664e-05, 'epoch': 0.27}
# {'loss': 3.8581, 'grad_norm': 26.676414489746094, 'learning_rate': 3.0266666666666666e-05, 'epoch': 0.4}
# {'loss': 3.6478, 'grad_norm': 32.532867431640625, 'learning_rate': 2.36e-05, 'epoch': 0.53}
# {'loss': 3.5096, 'grad_norm': 30.77223014831543, 'learning_rate': 1.6933333333333333e-05, 'epoch': 0.67}
# {'loss': 3.527, 'grad_norm': 21.969390869140625, 'learning_rate': 1.0266666666666668e-05, 'epoch': 0.8}
# {'loss': 3.4801, 'grad_norm': 32.17933654785156, 'learning_rate': 3.6e-06, 'epoch': 0.93}
# {'train_runtime': 89.8292, 'train_samples_per_second': 66.793, 'train_steps_per_second': 8.349, 'train_loss': 3.814614196777344, 'epoch': 1.0}
# 100% 750/750 [01:29<00:00,  8.35it/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/sarf_E2_seed_42_work/cpt/checkpoint and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /content/drive/MyDrive/SARF_BANKING_NLP_PROJECT/src_04/arabert_pipeline.py:328: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `TimedTrainer.__init__`. Use `processing_class` instead.
#   super().__init__(*args, **kwargs)
# {'loss': 4.3289, 'grad_norm': inf, 'learning_rate': 2e-05, 'epoch': 0.01}
# {'loss': 4.1308, 'grad_norm': 2.0747127532958984, 'learning_rate': 1.952694610778443e-05, 'epoch': 0.48}
# {'loss': 3.4438, 'grad_norm': 2.367810010910034, 'learning_rate': 1.9047904191616768e-05, 'epoch': 0.95}
#   5% 168/3340 [00:44<13:32,  3.91it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 45.07it/s]
#  26% 10/39 [00:00<00:00, 37.85it/s]
#  38% 15/39 [00:00<00:00, 37.02it/s]
#  49% 19/39 [00:00<00:00, 35.83it/s]
#  59% 23/39 [00:00<00:00, 32.69it/s]
#  69% 27/39 [00:00<00:00, 33.30it/s]
#  79% 31/39 [00:00<00:00, 33.60it/s]
#  90% 35/39 [00:01<00:00, 33.79it/s]
#
# {'eval_loss': 3.1874840259552, 'eval_macro_f1': 0.3637770036649148, 'eval_weighted_f1': 0.39086738159253787, 'eval_accuracy': 0.4369406021155411, 'eval_runtime': 1.2057, 'eval_samples_per_second': 1019.303, 'eval_steps_per_second': 32.346, 'epoch': 1.0}
#   5% 168/3340 [00:45<13:32,  3.91it/s]
# 100% 39/39 [00:01<00:00, 32.37it/s]
# {'loss': 2.7704, 'grad_norm': 4.070249080657959, 'learning_rate': 1.8568862275449104e-05, 'epoch': 1.43}
# {'loss': 2.3079, 'grad_norm': 3.601862668991089, 'learning_rate': 1.8095808383233534e-05, 'epoch': 1.91}
#  10% 336/3340 [01:36<11:25,  4.38it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 49.28it/s]
#  26% 10/39 [00:00<00:00, 39.18it/s]
#  38% 15/39 [00:00<00:00, 39.36it/s]
#  51% 20/39 [00:00<00:00, 37.82it/s]
#  62% 24/39 [00:00<00:00, 33.69it/s]
#  72% 28/39 [00:00<00:00, 35.38it/s]
#  85% 33/39 [00:00<00:00, 37.45it/s]
#
# {'eval_loss': 2.3680667877197266, 'eval_macro_f1': 0.5562502620785249, 'eval_weighted_f1': 0.5846331661930785, 'eval_accuracy': 0.6102522375915378, 'eval_runtime': 1.1149, 'eval_samples_per_second': 1102.367, 'eval_steps_per_second': 34.982, 'epoch': 2.0}
#  10% 336/3340 [01:37<11:25,  4.38it/s]
# 100% 39/39 [00:01<00:00, 35.74it/s]
# {'loss': 1.8903, 'grad_norm': 2.535696029663086, 'learning_rate': 1.761676646706587e-05, 'epoch': 2.38}
# {'loss': 1.551, 'grad_norm': 2.8037805557250977, 'learning_rate': 1.7137724550898204e-05, 'epoch': 2.86}
#  15% 504/3340 [02:51<11:10,  4.23it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 46.18it/s]
#  26% 10/39 [00:00<00:00, 37.75it/s]
#  38% 15/39 [00:00<00:00, 38.83it/s]
#  49% 19/39 [00:00<00:00, 37.78it/s]
#  59% 23/39 [00:00<00:00, 33.95it/s]
#  69% 27/39 [00:00<00:00, 34.49it/s]
#  79% 31/39 [00:00<00:00, 35.71it/s]
#
# {'eval_loss': 1.9101449251174927, 'eval_macro_f1': 0.6437182057142017, 'eval_weighted_f1': 0.6695960095263571, 'eval_accuracy': 0.6794141578519122, 'eval_runtime': 1.1296, 'eval_samples_per_second': 1088.035, 'eval_steps_per_second': 34.527, 'epoch': 3.0}
#  15% 504/3340 [02:52<11:10,  4.23it/s]
# 100% 39/39 [00:01<00:00, 37.63it/s]
# {'loss': 1.2756, 'grad_norm': 3.316244125366211, 'learning_rate': 1.665868263473054e-05, 'epoch': 3.33}
# {'loss': 1.095, 'grad_norm': 2.8093478679656982, 'learning_rate': 1.6179640718562873e-05, 'epoch': 3.81}
#  20% 672/3340 [03:46<10:37,  4.19it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 50.35it/s]
#  31% 12/39 [00:00<00:00, 40.05it/s]
#  44% 17/39 [00:00<00:00, 38.34it/s]
#  54% 21/39 [00:00<00:00, 35.71it/s]
#  64% 25/39 [00:00<00:00, 33.54it/s]
#  74% 29/39 [00:00<00:00, 34.79it/s]
#  87% 34/39 [00:00<00:00, 37.55it/s]
#
# {'eval_loss': 1.6820915937423706, 'eval_macro_f1': 0.6822899896005633, 'eval_weighted_f1': 0.7089760230060008, 'eval_accuracy': 0.7152156224572823, 'eval_runtime': 1.1349, 'eval_samples_per_second': 1082.918, 'eval_steps_per_second': 34.364, 'epoch': 4.0}
#  20% 672/3340 [03:47<10:37,  4.19it/s]
# 100% 39/39 [00:01<00:00, 34.08it/s]
# {'loss': 0.9277, 'grad_norm': 2.4645884037017822, 'learning_rate': 1.570059880239521e-05, 'epoch': 4.29}
# {'loss': 0.8055, 'grad_norm': 6.340281963348389, 'learning_rate': 1.5221556886227547e-05, 'epoch': 4.76}
#  25% 840/3340 [04:43<10:09,  4.10it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 46.83it/s]
#  26% 10/39 [00:00<00:00, 38.19it/s]
#  38% 15/39 [00:00<00:00, 38.88it/s]
#  49% 19/39 [00:00<00:00, 37.64it/s]
#  59% 23/39 [00:00<00:00, 33.85it/s]
#  69% 27/39 [00:00<00:00, 34.56it/s]
#  79% 31/39 [00:00<00:00, 35.81it/s]
#
# {'eval_loss': 1.574947476387024, 'eval_macro_f1': 0.7052579293769308, 'eval_weighted_f1': 0.7244523593662803, 'eval_accuracy': 0.7274206672091131, 'eval_runtime': 1.1354, 'eval_samples_per_second': 1082.427, 'eval_steps_per_second': 34.349, 'epoch': 5.0}
#  25% 840/3340 [04:44<10:09,  4.10it/s]
# 100% 39/39 [00:01<00:00, 38.28it/s]
# {'loss': 0.6948, 'grad_norm': 10.0567045211792, 'learning_rate': 1.4742514970059882e-05, 'epoch': 5.24}
# {'loss': 0.6303, 'grad_norm': 2.5042340755462646, 'learning_rate': 1.4263473053892217e-05, 'epoch': 5.72}
#  30% 1008/3340 [05:50<09:26,  4.11it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 48.72it/s]
#  26% 10/39 [00:00<00:00, 38.90it/s]
#  38% 15/39 [00:00<00:00, 37.71it/s]
#  49% 19/39 [00:00<00:00, 36.43it/s]
#  59% 23/39 [00:00<00:00, 33.11it/s]
#  69% 27/39 [00:00<00:00, 33.71it/s]
#  79% 31/39 [00:00<00:00, 34.19it/s]
#
# {'eval_loss': 1.517074704170227, 'eval_macro_f1': 0.7195141918465416, 'eval_weighted_f1': 0.7346726236119431, 'eval_accuracy': 0.7363710333604556, 'eval_runtime': 1.155, 'eval_samples_per_second': 1064.04, 'eval_steps_per_second': 33.765, 'epoch': 6.0}
#  30% 1008/3340 [05:52<09:26,  4.11it/s]
# 100% 39/39 [00:01<00:00, 36.57it/s]
# {'loss': 0.5632, 'grad_norm': 2.2478621006011963, 'learning_rate': 1.3784431137724551e-05, 'epoch': 6.19}
# {'loss': 0.5046, 'grad_norm': 2.5110936164855957, 'learning_rate': 1.3305389221556888e-05, 'epoch': 6.67}
#  35% 1176/3340 [06:47<08:28,  4.26it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 48.60it/s]
#  26% 10/39 [00:00<00:00, 39.39it/s]
#  38% 15/39 [00:00<00:00, 39.87it/s]
#  51% 20/39 [00:00<00:00, 37.96it/s]
#  62% 24/39 [00:00<00:00, 33.73it/s]
#  72% 28/39 [00:00<00:00, 35.20it/s]
#  82% 32/39 [00:00<00:00, 36.12it/s]
#
# {'eval_loss': 1.4996240139007568, 'eval_macro_f1': 0.7200401688666688, 'eval_weighted_f1': 0.7329013850896408, 'eval_accuracy': 0.7339300244100895, 'eval_runtime': 1.1366, 'eval_samples_per_second': 1081.285, 'eval_steps_per_second': 34.313, 'epoch': 7.0}
#  35% 1176/3340 [06:48<08:28,  4.26it/s]
# 100% 39/39 [00:01<00:00, 36.24it/s]
# {'loss': 0.4557, 'grad_norm': 2.111829996109009, 'learning_rate': 1.2826347305389221e-05, 'epoch': 7.14}
# {'loss': 0.4214, 'grad_norm': 2.729138135910034, 'learning_rate': 1.2347305389221558e-05, 'epoch': 7.62}
#  40% 1344/3340 [07:48<07:40,  4.33it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 50.08it/s]
#  31% 12/39 [00:00<00:00, 40.44it/s]
#  44% 17/39 [00:00<00:00, 38.44it/s]
#  54% 21/39 [00:00<00:00, 35.68it/s]
#  64% 25/39 [00:00<00:00, 33.50it/s]
#  74% 29/39 [00:00<00:00, 34.65it/s]
#  87% 34/39 [00:00<00:00, 37.48it/s]
#
# {'eval_loss': 1.4940217733383179, 'eval_macro_f1': 0.723434234660018, 'eval_weighted_f1': 0.7359566368160141, 'eval_accuracy': 0.7371847030105777, 'eval_runtime': 1.1214, 'eval_samples_per_second': 1095.969, 'eval_steps_per_second': 34.779, 'epoch': 8.0}
#  40% 1344/3340 [07:49<07:40,  4.33it/s]
# 100% 39/39 [00:01<00:00, 34.67it/s]
# {'loss': 0.3973, 'grad_norm': 2.922150135040283, 'learning_rate': 1.1868263473053894e-05, 'epoch': 8.1}
# {'loss': 0.3403, 'grad_norm': 3.0748379230499268, 'learning_rate': 1.1389221556886228e-05, 'epoch': 8.57}
#  45% 1512/3340 [08:55<07:06,  4.29it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 47.19it/s]
#  26% 10/39 [00:00<00:00, 37.86it/s]
#  38% 15/39 [00:00<00:00, 36.95it/s]
#  49% 19/39 [00:00<00:00, 36.24it/s]
#  59% 23/39 [00:00<00:00, 32.48it/s]
#  69% 27/39 [00:00<00:00, 33.78it/s]
#  79% 31/39 [00:00<00:00, 34.40it/s]
#
# {'eval_loss': 1.486159086227417, 'eval_macro_f1': 0.7284104597240889, 'eval_weighted_f1': 0.7399671026450872, 'eval_accuracy': 0.7404393816110659, 'eval_runtime': 1.1655, 'eval_samples_per_second': 1054.448, 'eval_steps_per_second': 33.461, 'epoch': 9.0}
#  45% 1512/3340 [08:56<07:06,  4.29it/s]
# 100% 39/39 [00:01<00:00, 36.66it/s]
# {'loss': 0.3512, 'grad_norm': 1.9780627489089966, 'learning_rate': 1.0910179640718563e-05, 'epoch': 9.05}
# {'loss': 0.3131, 'grad_norm': 2.460306167602539, 'learning_rate': 1.04311377245509e-05, 'epoch': 9.52}
# {'loss': 0.2936, 'grad_norm': 1.0693978071212769, 'learning_rate': 9.952095808383234e-06, 'epoch': 10.0}
#  50% 1680/3340 [10:01<06:32,  4.23it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 40.84it/s]
#  26% 10/39 [00:00<00:00, 38.03it/s]
#  38% 15/39 [00:00<00:00, 37.75it/s]
#  49% 19/39 [00:00<00:00, 36.34it/s]
#  59% 23/39 [00:00<00:00, 32.23it/s]
#  69% 27/39 [00:00<00:00, 32.58it/s]
#  79% 31/39 [00:00<00:00, 33.56it/s]
#
# {'eval_loss': 1.4845365285873413, 'eval_macro_f1': 0.7294604404622572, 'eval_weighted_f1': 0.7408567441799482, 'eval_accuracy': 0.741253051261188, 'eval_runtime': 1.157, 'eval_samples_per_second': 1062.236, 'eval_steps_per_second': 33.708, 'epoch': 10.0}
#  50% 1680/3340 [10:03<06:32,  4.23it/s]
# 100% 39/39 [00:01<00:00, 35.70it/s]
# {'loss': 0.2674, 'grad_norm': 1.74924635887146, 'learning_rate': 9.47305389221557e-06, 'epoch': 10.48}
# {'loss': 0.259, 'grad_norm': 3.086081027984619, 'learning_rate': 8.994011976047906e-06, 'epoch': 10.95}
#  55% 1848/3340 [11:04<06:08,  4.05it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 49.28it/s]
#  28% 11/39 [00:00<00:00, 39.29it/s]
#  41% 16/39 [00:00<00:00, 37.42it/s]
#  51% 20/39 [00:00<00:00, 36.56it/s]
#  62% 24/39 [00:00<00:00, 32.54it/s]
#  72% 28/39 [00:00<00:00, 34.29it/s]
#  82% 32/39 [00:00<00:00, 35.53it/s]
#
# {'eval_loss': 1.4925153255462646, 'eval_macro_f1': 0.7274496708406616, 'eval_weighted_f1': 0.7387161941019967, 'eval_accuracy': 0.7396257119609438, 'eval_runtime': 1.1482, 'eval_samples_per_second': 1070.333, 'eval_steps_per_second': 33.965, 'epoch': 11.0}
#  55% 1848/3340 [11:05<06:08,  4.05it/s]
# 100% 39/39 [00:01<00:00, 36.17it/s]
# {'loss': 0.2375, 'grad_norm': 2.9288570880889893, 'learning_rate': 8.51497005988024e-06, 'epoch': 11.43}
# {'loss': 0.2318, 'grad_norm': 4.351235866546631, 'learning_rate': 8.035928143712575e-06, 'epoch': 11.91}
#  60% 2016/3340 [12:00<05:18,  4.16it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 44.73it/s]
#  26% 10/39 [00:00<00:00, 37.98it/s]
#  38% 15/39 [00:00<00:00, 38.71it/s]
#  49% 19/39 [00:00<00:00, 37.70it/s]
#  59% 23/39 [00:00<00:00, 33.95it/s]
#  69% 27/39 [00:00<00:00, 34.38it/s]
#  79% 31/39 [00:00<00:00, 35.19it/s]
#
# {'eval_loss': 1.5014101266860962, 'eval_macro_f1': 0.7288979496131541, 'eval_weighted_f1': 0.739742693684307, 'eval_accuracy': 0.7404393816110659, 'eval_runtime': 1.1422, 'eval_samples_per_second': 1075.986, 'eval_steps_per_second': 34.144, 'epoch': 12.0}
#  60% 2016/3340 [12:01<05:18,  4.16it/s]
# 100% 39/39 [00:01<00:00, 36.83it/s]
# {'loss': 0.2141, 'grad_norm': 2.911329984664917, 'learning_rate': 7.55688622754491e-06, 'epoch': 12.38}
# {'loss': 0.207, 'grad_norm': 0.5938146710395813, 'learning_rate': 7.077844311377246e-06, 'epoch': 12.86}
#  65% 2184/3340 [12:55<04:32,  4.24it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 47.77it/s]
#  26% 10/39 [00:00<00:00, 38.83it/s]
#  38% 15/39 [00:00<00:00, 38.74it/s]
#  49% 19/39 [00:00<00:00, 37.44it/s]
#  59% 23/39 [00:00<00:00, 33.89it/s]
#  69% 27/39 [00:00<00:00, 34.57it/s]
#  79% 31/39 [00:00<00:00, 35.78it/s]
#
# {'eval_loss': 1.498734712600708, 'eval_macro_f1': 0.7243659178122475, 'eval_weighted_f1': 0.7356149010360536, 'eval_accuracy': 0.7363710333604556, 'eval_runtime': 1.1259, 'eval_samples_per_second': 1091.612, 'eval_steps_per_second': 34.64, 'epoch': 13.0}
#  65% 2184/3340 [12:56<04:32,  4.24it/s]
# 100% 39/39 [00:01<00:00, 38.14it/s]
# {'train_runtime': 796.4331, 'train_samples_per_second': 269.502, 'train_steps_per_second': 4.194, 'train_loss': 0.9762107441713522, 'epoch': 13.0}
#  65% 2184/3340 [13:16<07:01,  2.74it/s]
# 100% 39/39 [00:01<00:00, 37.24it/s]
# {
#   "run_id": "E2_seed_42",
#   "owner": "A",
#   "model_family": "AraBERTv2-base",
#   "condition": "E2",
#   "run_type": "official",
#   "seed": 42,
#   "base_checkpoint": "aubmindlab/bert-base-arabertv2",
#   "config_id": "arabert_config",
#   "train_split": "msa_train_v1",
#   "validation_split": "msa_val_v1",
#   "train_rows": 10732,
#   "validation_rows": 1229,
#   "num_labels": 77,
#   "cpt_corpus_files": [
#     "general_6k_final_v2.csv"
#   ],
#   "cpt_details": {
#     "condition": "E2",
#     "corpus_files": [
#       "general_6k_final_v2.csv"
#     ],
#     "corpus_file_rows": {
#       "general_6k_final_v2.csv": 6000
#     },
#     "total_rows": 6000,
#     "text_column_only": true,
#     "objective": "masked_language_modeling",
#     "epochs": 1,
#     "training_loss": 3.814614196777344
#   },
#   "checkpoint_selection_metric": "macro_f1 on MSA validation",
#   "best_epoch": 10.0,
#   "metrics": {
#     "macro_f1": 0.7294604404622572,
#     "weighted_f1": 0.7408567441799482,
#     "accuracy": 0.741253051261188
#   },
#   "prediction_file": "validation_predictions.csv",
#   "per_class_file": "per_class_metrics.csv",
#   "confusion_matrix_file": "confusion_matrix.csv",
#   "runtime_seconds": {
#     "loading_and_tokenization_seconds": 10.265620270999989,
#     "cpt_seconds": 101.4597995470001,
#     "fine_tuning_seconds": 581.1645526470004,
#     "validation_during_training_seconds": 14.927645102999804,
#     "checkpoint_saving_during_training_seconds": 200.78260523399967,
#     "final_validation_export_reload_seconds": 5.007669868999983,
#     "validation_and_checkpoint_saving_seconds": 220.71792020599946,
#     "total_runtime_seconds": 913.607892671,
#     "total_runtime_definition": "Sum of measured loading/tokenization, CPT when applicable, fine-tuning, validation, checkpoint saving, export, and reload steps."
#   },
#   "truncation_audit": {
#     "max_length": 128,
#     "train_truncation_rate": 0.0,
#     "validation_truncation_rate": 0.0,
#     "train_max_untruncated_length": 111,
#     "validation_max_untruncated_length": 103
#   },
#   "checks": {
#     "labels_77_verified": true,
#     "logits_shape_verified": [
#       1229,
#       77
#     ],
#     "predictions_not_single_label": true,
#     "best_checkpoint_selected_by_macro_f1": true,
#     "checkpoint_reload_passed": true,
#     "approved_msa_inputs_only": true,
#     "zero_truncation_at_frozen_max_length": true,
#     "fresh_base_checkpoint_used": true
#   },
#   "saudi_test_accessed": false,
#   "status": "completed"
# }

# %%
SEED = 123
assert SEED in [42, 123, 2026]

# !python "{PIPELINE_PATH}" --project-root "{PROJECT_ROOT}" --condition "E2" --seed {SEED}
# Out:
# 2026-09-12 08:04:06.422710: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-09-12 08:04:12,376 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# Map: 100% 10732/10732 [00:00<00:00, 12117.97 examples/s]
# Map: 100% 1229/1229 [00:00<00:00, 11762.72 examples/s]
# Tokenizing approved E2 CPT corpus: 100% 6000/6000 [00:00<00:00, 13343.33 examples/s]
# BertForMaskedLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Some weights of the model checkpoint at aubmindlab/bert-base-arabertv2 were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /content/drive/MyDrive/SARF_BANKING_NLP_PROJECT/src_04/arabert_pipeline.py:437: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# {'loss': 4.7477, 'grad_norm': 27.668643951416016, 'learning_rate': 4.353333333333334e-05, 'epoch': 0.13}
# {'loss': 4.1878, 'grad_norm': 23.303831100463867, 'learning_rate': 3.6933333333333334e-05, 'epoch': 0.27}
# {'loss': 3.9697, 'grad_norm': 24.3583984375, 'learning_rate': 3.0266666666666666e-05, 'epoch': 0.4}
# {'loss': 3.7088, 'grad_norm': 22.092741012573242, 'learning_rate': 2.36e-05, 'epoch': 0.53}
# {'loss': 3.4386, 'grad_norm': 30.948930740356445, 'learning_rate': 1.6933333333333333e-05, 'epoch': 0.67}
# {'loss': 3.5905, 'grad_norm': 21.25578498840332, 'learning_rate': 1.0333333333333333e-05, 'epoch': 0.8}
# {'loss': 3.5692, 'grad_norm': 20.896631240844727, 'learning_rate': 3.666666666666667e-06, 'epoch': 0.93}
# {'train_runtime': 89.7008, 'train_samples_per_second': 66.889, 'train_steps_per_second': 8.361, 'train_loss': 3.841287618001302, 'epoch': 1.0}
# 100% 750/750 [01:29<00:00,  8.36it/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/sarf_E2_seed_123_work/cpt/checkpoint and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /content/drive/MyDrive/SARF_BANKING_NLP_PROJECT/src_04/arabert_pipeline.py:328: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `TimedTrainer.__init__`. Use `processing_class` instead.
#   super().__init__(*args, **kwargs)
# {'loss': 4.3645, 'grad_norm': 1.5749561786651611, 'learning_rate': 1.9994011976047905e-05, 'epoch': 0.01}
# {'loss': 4.1155, 'grad_norm': 1.948644995689392, 'learning_rate': 1.953293413173653e-05, 'epoch': 0.48}
# {'loss': 3.4238, 'grad_norm': 2.536390781402588, 'learning_rate': 1.9053892215568864e-05, 'epoch': 0.95}
#   5% 168/3340 [00:44<13:41,  3.86it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 46.03it/s]
#  26% 10/39 [00:00<00:00, 37.38it/s]
#  36% 14/39 [00:00<00:00, 38.02it/s]
#  46% 18/39 [00:00<00:00, 34.49it/s]
#  56% 22/39 [00:00<00:00, 31.71it/s]
#  67% 26/39 [00:00<00:00, 32.44it/s]
#  77% 30/39 [00:00<00:00, 32.55it/s]
#  90% 35/39 [00:01<00:00, 34.74it/s]
#
# {'eval_loss': 3.152942180633545, 'eval_macro_f1': 0.4005645969865848, 'eval_weighted_f1': 0.43460419283339125, 'eval_accuracy': 0.4751830756712775, 'eval_runtime': 1.2121, 'eval_samples_per_second': 1013.973, 'eval_steps_per_second': 32.177, 'epoch': 1.0}
#   5% 168/3340 [00:45<13:41,  3.86it/s]
# 100% 39/39 [00:01<00:00, 33.07it/s]
# {'loss': 2.752, 'grad_norm': 2.751422882080078, 'learning_rate': 1.85748502994012e-05, 'epoch': 1.43}
# {'loss': 2.2518, 'grad_norm': 2.4419403076171875, 'learning_rate': 1.8095808383233534e-05, 'epoch': 1.91}
#  10% 336/3340 [01:48<11:52,  4.21it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 47.70it/s]
#  26% 10/39 [00:00<00:00, 37.78it/s]
#  38% 15/39 [00:00<00:00, 38.53it/s]
#  49% 19/39 [00:00<00:00, 37.24it/s]
#  59% 23/39 [00:00<00:00, 33.80it/s]
#  69% 27/39 [00:00<00:00, 34.33it/s]
#  79% 31/39 [00:00<00:00, 35.04it/s]
#
# {'eval_loss': 2.32330584526062, 'eval_macro_f1': 0.5489846916343462, 'eval_weighted_f1': 0.5865686020601227, 'eval_accuracy': 0.611879576891782, 'eval_runtime': 1.1551, 'eval_samples_per_second': 1063.955, 'eval_steps_per_second': 33.763, 'epoch': 2.0}
#  10% 336/3340 [01:49<11:52,  4.21it/s]
# 100% 39/39 [00:01<00:00, 36.43it/s]
# {'loss': 1.807, 'grad_norm': 2.771946430206299, 'learning_rate': 1.761676646706587e-05, 'epoch': 2.38}
# {'loss': 1.4971, 'grad_norm': 2.671481132507324, 'learning_rate': 1.7137724550898204e-05, 'epoch': 2.86}
#  15% 504/3340 [02:46<11:50,  3.99it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 46.53it/s]
#  26% 10/39 [00:00<00:00, 37.86it/s]
#  36% 14/39 [00:00<00:00, 37.38it/s]
#  46% 18/39 [00:00<00:00, 35.33it/s]
#  56% 22/39 [00:00<00:00, 32.16it/s]
#  67% 26/39 [00:00<00:00, 32.12it/s]
#  77% 30/39 [00:00<00:00, 32.97it/s]
#  87% 34/39 [00:00<00:00, 34.74it/s]
#
# {'eval_loss': 1.8841766119003296, 'eval_macro_f1': 0.6369395420299642, 'eval_weighted_f1': 0.667462947424434, 'eval_accuracy': 0.6794141578519122, 'eval_runtime': 1.2025, 'eval_samples_per_second': 1022.021, 'eval_steps_per_second': 32.432, 'epoch': 3.0}
#  15% 504/3340 [02:47<11:50,  3.99it/s]
# 100% 39/39 [00:01<00:00, 32.39it/s]
# {'loss': 1.2564, 'grad_norm': 2.810103416442871, 'learning_rate': 1.665868263473054e-05, 'epoch': 3.33}
# {'loss': 1.0508, 'grad_norm': 2.692261219024658, 'learning_rate': 1.6179640718562873e-05, 'epoch': 3.81}
#  20% 672/3340 [03:49<10:32,  4.22it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 48.65it/s]
#  28% 11/39 [00:00<00:00, 39.50it/s]
#  41% 16/39 [00:00<00:00, 37.99it/s]
#  51% 20/39 [00:00<00:00, 37.05it/s]
#  62% 24/39 [00:00<00:00, 32.55it/s]
#  72% 28/39 [00:00<00:00, 34.41it/s]
#  82% 32/39 [00:00<00:00, 35.71it/s]
#
# {'eval_loss': 1.6732375621795654, 'eval_macro_f1': 0.6734679093390271, 'eval_weighted_f1': 0.6992444966611453, 'eval_accuracy': 0.7062652563059398, 'eval_runtime': 1.1463, 'eval_samples_per_second': 1072.138, 'eval_steps_per_second': 34.022, 'epoch': 4.0}
#  20% 672/3340 [03:50<10:32,  4.22it/s]
# 100% 39/39 [00:01<00:00, 36.72it/s]
# {'loss': 0.8895, 'grad_norm': 2.904181718826294, 'learning_rate': 1.570059880239521e-05, 'epoch': 4.29}
# {'loss': 0.8052, 'grad_norm': 3.2325408458709717, 'learning_rate': 1.5221556886227547e-05, 'epoch': 4.76}
#  25% 840/3340 [04:48<10:05,  4.13it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 49.84it/s]
#  28% 11/39 [00:00<00:00, 39.95it/s]
#  41% 16/39 [00:00<00:00, 38.38it/s]
#  51% 20/39 [00:00<00:00, 37.52it/s]
#  62% 24/39 [00:00<00:00, 32.79it/s]
#  72% 28/39 [00:00<00:00, 34.48it/s]
#  85% 33/39 [00:00<00:00, 36.14it/s]
#
# {'eval_loss': 1.565083384513855, 'eval_macro_f1': 0.6991320403870513, 'eval_weighted_f1': 0.7204535552530004, 'eval_accuracy': 0.724979658258747, 'eval_runtime': 1.1424, 'eval_samples_per_second': 1075.812, 'eval_steps_per_second': 34.139, 'epoch': 5.0}
#  25% 840/3340 [04:49<10:05,  4.13it/s]
# 100% 39/39 [00:01<00:00, 34.44it/s]
# {'loss': 0.67, 'grad_norm': 2.686415195465088, 'learning_rate': 1.4742514970059882e-05, 'epoch': 5.24}
# {'loss': 0.6224, 'grad_norm': 2.6278955936431885, 'learning_rate': 1.4263473053892217e-05, 'epoch': 5.72}
#  30% 1008/3340 [05:50<09:27,  4.11it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 48.50it/s]
#  28% 11/39 [00:00<00:00, 39.03it/s]
#  38% 15/39 [00:00<00:00, 37.44it/s]
#  49% 19/39 [00:00<00:00, 36.33it/s]
#  59% 23/39 [00:00<00:00, 33.29it/s]
#  69% 27/39 [00:00<00:00, 34.02it/s]
#  79% 31/39 [00:00<00:00, 35.16it/s]
#
# {'eval_loss': 1.5306127071380615, 'eval_macro_f1': 0.7069620824673091, 'eval_weighted_f1': 0.7216573848035389, 'eval_accuracy': 0.7241659886086249, 'eval_runtime': 1.1473, 'eval_samples_per_second': 1071.252, 'eval_steps_per_second': 33.994, 'epoch': 6.0}
#  30% 1008/3340 [05:51<09:27,  4.11it/s]
# 100% 39/39 [00:01<00:00, 36.80it/s]
# {'loss': 0.5368, 'grad_norm': 3.1383378505706787, 'learning_rate': 1.3784431137724551e-05, 'epoch': 6.19}
# {'loss': 0.4991, 'grad_norm': 2.7986602783203125, 'learning_rate': 1.3305389221556888e-05, 'epoch': 6.67}
#  35% 1176/3340 [06:43<10:13,  3.53it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 44.24it/s]
#  26% 10/39 [00:00<00:00, 37.28it/s]
#  38% 15/39 [00:00<00:00, 36.61it/s]
#  49% 19/39 [00:00<00:00, 35.68it/s]
#  59% 23/39 [00:00<00:00, 31.54it/s]
#  69% 27/39 [00:00<00:00, 31.15it/s]
#  79% 31/39 [00:00<00:00, 33.45it/s]
#
# {'eval_loss': 1.501465916633606, 'eval_macro_f1': 0.7220976430449465, 'eval_weighted_f1': 0.7347956369397496, 'eval_accuracy': 0.7355573637103336, 'eval_runtime': 1.1927, 'eval_samples_per_second': 1030.425, 'eval_steps_per_second': 32.699, 'epoch': 7.0}
#  35% 1176/3340 [06:44<10:13,  3.53it/s]
# 100% 39/39 [00:01<00:00, 35.73it/s]
# {'loss': 0.4434, 'grad_norm': 1.992145299911499, 'learning_rate': 1.2826347305389221e-05, 'epoch': 7.14}
# {'loss': 0.4175, 'grad_norm': 2.044600248336792, 'learning_rate': 1.2353293413173652e-05, 'epoch': 7.62}
#  40% 1344/3340 [07:43<07:51,  4.23it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 46.54it/s]
#  26% 10/39 [00:00<00:00, 39.07it/s]
#  38% 15/39 [00:00<00:00, 39.60it/s]
#  51% 20/39 [00:00<00:00, 37.78it/s]
#  62% 24/39 [00:00<00:00, 33.45it/s]
#  72% 28/39 [00:00<00:00, 35.18it/s]
#  85% 33/39 [00:00<00:00, 37.40it/s]
#
# {'eval_loss': 1.4942655563354492, 'eval_macro_f1': 0.7244590437044812, 'eval_weighted_f1': 0.7361308734372682, 'eval_accuracy': 0.7363710333604556, 'eval_runtime': 1.1196, 'eval_samples_per_second': 1097.749, 'eval_steps_per_second': 34.835, 'epoch': 8.0}
#  40% 1344/3340 [07:44<07:51,  4.23it/s]
# 100% 39/39 [00:01<00:00, 35.78it/s]
# {'loss': 0.3883, 'grad_norm': 1.7594549655914307, 'learning_rate': 1.1874251497005989e-05, 'epoch': 8.1}
# {'loss': 0.3506, 'grad_norm': 2.8937971591949463, 'learning_rate': 1.1395209580838324e-05, 'epoch': 8.57}
#  45% 1512/3340 [08:56<07:22,  4.13it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 40.94it/s]
#  26% 10/39 [00:00<00:00, 35.47it/s]
#  38% 15/39 [00:00<00:00, 35.11it/s]
#  49% 19/39 [00:00<00:00, 34.65it/s]
#  59% 23/39 [00:00<00:00, 31.28it/s]
#  69% 27/39 [00:00<00:00, 32.70it/s]
#  79% 31/39 [00:00<00:00, 33.59it/s]
#  90% 35/39 [00:01<00:00, 34.65it/s]
#
# {'eval_loss': 1.474640130996704, 'eval_macro_f1': 0.7290340290475202, 'eval_weighted_f1': 0.7407095496480202, 'eval_accuracy': 0.741253051261188, 'eval_runtime': 1.2082, 'eval_samples_per_second': 1017.228, 'eval_steps_per_second': 32.28, 'epoch': 9.0}
#  45% 1512/3340 [08:57<07:22,  4.13it/s]
# 100% 39/39 [00:01<00:00, 33.36it/s]
# {'loss': 0.3318, 'grad_norm': 2.6891708374023438, 'learning_rate': 1.091616766467066e-05, 'epoch': 9.05}
# {'loss': 0.3126, 'grad_norm': 2.3269035816192627, 'learning_rate': 1.0437125748502994e-05, 'epoch': 9.52}
# {'loss': 0.2782, 'grad_norm': 4.053079128265381, 'learning_rate': 9.95808383233533e-06, 'epoch': 10.0}
#  50% 1680/3340 [09:52<06:43,  4.12it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 48.26it/s]
#  28% 11/39 [00:00<00:00, 36.70it/s]
#  38% 15/39 [00:00<00:00, 35.25it/s]
#  49% 19/39 [00:00<00:00, 35.12it/s]
#  59% 23/39 [00:00<00:00, 32.16it/s]
#  69% 27/39 [00:00<00:00, 32.84it/s]
#  79% 31/39 [00:00<00:00, 33.55it/s]
#  90% 35/39 [00:00<00:00, 35.24it/s]
#
# {'eval_loss': 1.492557406425476, 'eval_macro_f1': 0.7256210865061353, 'eval_weighted_f1': 0.7369071264340815, 'eval_accuracy': 0.7379983726606998, 'eval_runtime': 1.1671, 'eval_samples_per_second': 1053.018, 'eval_steps_per_second': 33.416, 'epoch': 10.0}
#  50% 1680/3340 [09:53<06:43,  4.12it/s]
# 100% 39/39 [00:01<00:00, 33.68it/s]
# {'loss': 0.2598, 'grad_norm': 0.7380378246307373, 'learning_rate': 9.479041916167665e-06, 'epoch': 10.48}
# {'loss': 0.2736, 'grad_norm': 2.4767138957977295, 'learning_rate': 9e-06, 'epoch': 10.95}
#  55% 1848/3340 [10:53<06:13,  3.99it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 48.03it/s]
#  26% 10/39 [00:00<00:00, 38.48it/s]
#  38% 15/39 [00:00<00:00, 38.96it/s]
#  49% 19/39 [00:00<00:00, 37.81it/s]
#  59% 23/39 [00:00<00:00, 34.27it/s]
#  69% 27/39 [00:00<00:00, 34.67it/s]
#  79% 31/39 [00:00<00:00, 36.03it/s]
#
# {'eval_loss': 1.4917781352996826, 'eval_macro_f1': 0.722003773585049, 'eval_weighted_f1': 0.7354071739949385, 'eval_accuracy': 0.7363710333604556, 'eval_runtime': 1.118, 'eval_samples_per_second': 1099.243, 'eval_steps_per_second': 34.882, 'epoch': 11.0}
#  55% 1848/3340 [10:54<06:13,  3.99it/s]
# 100% 39/39 [00:01<00:00, 38.38it/s]
# {'loss': 0.227, 'grad_norm': 1.4748750925064087, 'learning_rate': 8.520958083832335e-06, 'epoch': 11.43}
# {'loss': 0.2301, 'grad_norm': 1.7834008932113647, 'learning_rate': 8.041916167664672e-06, 'epoch': 11.91}
#  60% 2016/3340 [11:49<05:33,  3.97it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 48.97it/s]
#  26% 10/39 [00:00<00:00, 38.95it/s]
#  38% 15/39 [00:00<00:00, 38.15it/s]
#  49% 19/39 [00:00<00:00, 37.02it/s]
#  59% 23/39 [00:00<00:00, 33.15it/s]
#  69% 27/39 [00:00<00:00, 34.05it/s]
#  79% 31/39 [00:00<00:00, 35.22it/s]
#
# {'eval_loss': 1.4952178001403809, 'eval_macro_f1': 0.7295537620389553, 'eval_weighted_f1': 0.7415476775562255, 'eval_accuracy': 0.74206672091131, 'eval_runtime': 1.134, 'eval_samples_per_second': 1083.73, 'eval_steps_per_second': 34.39, 'epoch': 12.0}
#  60% 2016/3340 [11:50<05:33,  3.97it/s]
# 100% 39/39 [00:01<00:00, 37.52it/s]
# {'loss': 0.21, 'grad_norm': 3.891796827316284, 'learning_rate': 7.562874251497007e-06, 'epoch': 12.38}
# {'loss': 0.2138, 'grad_norm': 3.805805206298828, 'learning_rate': 7.083832335329342e-06, 'epoch': 12.86}
#  65% 2184/3340 [12:52<05:09,  3.74it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 42.90it/s]
#  26% 10/39 [00:00<00:00, 37.02it/s]
#  36% 14/39 [00:00<00:00, 36.44it/s]
#  46% 18/39 [00:00<00:00, 34.54it/s]
#  56% 22/39 [00:00<00:00, 31.21it/s]
#  67% 26/39 [00:00<00:00, 31.45it/s]
#  77% 30/39 [00:00<00:00, 32.25it/s]
#  90% 35/39 [00:01<00:00, 34.46it/s]
#
# {'eval_loss': 1.5017491579055786, 'eval_macro_f1': 0.731260521748519, 'eval_weighted_f1': 0.7432522302835581, 'eval_accuracy': 0.7436940602115542, 'eval_runtime': 1.2266, 'eval_samples_per_second': 1001.928, 'eval_steps_per_second': 31.794, 'epoch': 13.0}
#  65% 2184/3340 [12:53<05:09,  3.74it/s]
# 100% 39/39 [00:01<00:00, 32.66it/s]
# {'loss': 0.1914, 'grad_norm': 1.3036836385726929, 'learning_rate': 6.604790419161677e-06, 'epoch': 13.33}
# {'loss': 0.1951, 'grad_norm': 2.93757700920105, 'learning_rate': 6.125748502994012e-06, 'epoch': 13.81}
#  70% 2352/3340 [13:58<03:49,  4.30it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 46.54it/s]
#  26% 10/39 [00:00<00:00, 38.09it/s]
#  38% 15/39 [00:00<00:00, 37.23it/s]
#  49% 19/39 [00:00<00:00, 35.86it/s]
#  59% 23/39 [00:00<00:00, 31.84it/s]
#  69% 27/39 [00:00<00:00, 32.52it/s]
#  79% 31/39 [00:00<00:00, 33.59it/s]
#
# {'eval_loss': 1.500672459602356, 'eval_macro_f1': 0.726136577719012, 'eval_weighted_f1': 0.7379336415908307, 'eval_accuracy': 0.7388120423108218, 'eval_runtime': 1.1895, 'eval_samples_per_second': 1033.226, 'eval_steps_per_second': 32.787, 'epoch': 14.0}
#  70% 2352/3340 [13:59<03:49,  4.30it/s]
# 100% 39/39 [00:01<00:00, 35.49it/s]
# {'loss': 0.1717, 'grad_norm': 1.7672412395477295, 'learning_rate': 5.646706586826348e-06, 'epoch': 14.29}
# {'loss': 0.1777, 'grad_norm': 2.0218489170074463, 'learning_rate': 5.167664670658683e-06, 'epoch': 14.76}
#  75% 2520/3340 [14:49<03:12,  4.26it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 47.24it/s]
#  26% 10/39 [00:00<00:00, 38.35it/s]
#  38% 15/39 [00:00<00:00, 39.25it/s]
#  49% 19/39 [00:00<00:00, 37.50it/s]
#  59% 23/39 [00:00<00:00, 34.19it/s]
#  69% 27/39 [00:00<00:00, 35.45it/s]
#  79% 31/39 [00:00<00:00, 35.97it/s]
#
# {'eval_loss': 1.509443759918213, 'eval_macro_f1': 0.7286979875272339, 'eval_weighted_f1': 0.7410218917956856, 'eval_accuracy': 0.741253051261188, 'eval_runtime': 1.1269, 'eval_samples_per_second': 1090.599, 'eval_steps_per_second': 34.608, 'epoch': 15.0}
#  75% 2520/3340 [14:51<03:12,  4.26it/s]
# 100% 39/39 [00:01<00:00, 38.00it/s]
# {'loss': 0.1595, 'grad_norm': 1.9534379243850708, 'learning_rate': 4.688622754491019e-06, 'epoch': 15.24}
# {'loss': 0.1534, 'grad_norm': 1.9570029973983765, 'learning_rate': 4.209580838323354e-06, 'epoch': 15.72}
#  80% 2688/3340 [15:56<02:42,  4.01it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 48.28it/s]
#  26% 10/39 [00:00<00:00, 38.49it/s]
#  38% 15/39 [00:00<00:00, 37.39it/s]
#  49% 19/39 [00:00<00:00, 36.37it/s]
#  59% 23/39 [00:00<00:00, 33.32it/s]
#  69% 27/39 [00:00<00:00, 34.10it/s]
#  79% 31/39 [00:00<00:00, 35.49it/s]
#
# {'eval_loss': 1.5250790119171143, 'eval_macro_f1': 0.7300814425612187, 'eval_weighted_f1': 0.7423295029732264, 'eval_accuracy': 0.7428803905614321, 'eval_runtime': 1.1331, 'eval_samples_per_second': 1084.593, 'eval_steps_per_second': 34.418, 'epoch': 16.0}
#  80% 2688/3340 [15:57<02:42,  4.01it/s]
# 100% 39/39 [00:01<00:00, 37.94it/s]
# {'train_runtime': 979.8044, 'train_samples_per_second': 219.064, 'train_steps_per_second': 3.409, 'train_loss': 0.81153937180837, 'epoch': 16.0}
#  80% 2688/3340 [16:19<03:57,  2.74it/s]
# 100% 39/39 [00:01<00:00, 38.01it/s]
# {
#   "run_id": "E2_seed_123",
#   "owner": "A",
#   "model_family": "AraBERTv2-base",
#   "condition": "E2",
#   "run_type": "official",
#   "seed": 123,
#   "base_checkpoint": "aubmindlab/bert-base-arabertv2",
#   "config_id": "arabert_config",
#   "train_split": "msa_train_v1",
#   "validation_split": "msa_val_v1",
#   "train_rows": 10732,
#   "validation_rows": 1229,
#   "num_labels": 77,
#   "cpt_corpus_files": [
#     "general_6k_final_v2.csv"
#   ],
#   "cpt_details": {
#     "condition": "E2",
#     "corpus_files": [
#       "general_6k_final_v2.csv"
#     ],
#     "corpus_file_rows": {
#       "general_6k_final_v2.csv": 6000
#     },
#     "total_rows": 6000,
#     "text_column_only": true,
#     "objective": "masked_language_modeling",
#     "epochs": 1,
#     "training_loss": 3.841287618001302
#   },
#   "checkpoint_selection_metric": "macro_f1 on MSA validation",
#   "best_epoch": 13.0,
#   "metrics": {
#     "macro_f1": 0.731260521748519,
#     "weighted_f1": 0.7432522302835581,
#     "accuracy": 0.7436940602115542
#   },
#   "prediction_file": "validation_predictions.csv",
#   "per_class_file": "per_class_metrics.csv",
#   "confusion_matrix_file": "confusion_matrix.csv",
#   "runtime_seconds": {
#     "loading_and_tokenization_seconds": 10.14667926400034,
#     "cpt_seconds": 102.36888404799993,
#     "fine_tuning_seconds": 719.494398158999,
#     "validation_during_training_seconds": 18.694478361001075,
#     "checkpoint_saving_during_training_seconds": 242.10538671199993,
#     "final_validation_export_reload_seconds": 4.817744517999927,
#     "validation_and_checkpoint_saving_seconds": 265.6176095910009,
#     "total_runtime_seconds": 1097.6275710620002,
#     "total_runtime_definition": "Sum of measured loading/tokenization, CPT when applicable, fine-tuning, validation, checkpoint saving, export, and reload steps."
#   },
#   "truncation_audit": {
#     "max_length": 128,
#     "train_truncation_rate": 0.0,
#     "validation_truncation_rate": 0.0,
#     "train_max_untruncated_length": 111,
#     "validation_max_untruncated_length": 103
#   },
#   "checks": {
#     "labels_77_verified": true,
#     "logits_shape_verified": [
#       1229,
#       77
#     ],
#     "predictions_not_single_label": true,
#     "best_checkpoint_selected_by_macro_f1": true,
#     "checkpoint_reload_passed": true,
#     "approved_msa_inputs_only": true,
#     "zero_truncation_at_frozen_max_length": true,
#     "fresh_base_checkpoint_used": true
#   },
#   "saudi_test_accessed": false,
#   "status": "completed"
# }

# %%
SEED = 2026
assert SEED in [42, 123, 2026]

# !python "{PIPELINE_PATH}" --project-root "{PROJECT_ROOT}" --condition "E2" --seed {SEED}
# Out:
# 2026-09-12 08:23:04.542253: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-09-12 08:23:11,410 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# Map: 100% 10732/10732 [00:01<00:00, 7450.61 examples/s]
# Map: 100% 1229/1229 [00:00<00:00, 9262.38 examples/s]
# Tokenizing approved E2 CPT corpus: 100% 6000/6000 [00:00<00:00, 13241.63 examples/s]
# BertForMaskedLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Some weights of the model checkpoint at aubmindlab/bert-base-arabertv2 were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /content/drive/MyDrive/SARF_BANKING_NLP_PROJECT/src_04/arabert_pipeline.py:437: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# {'loss': 4.6739, 'grad_norm': 32.039920806884766, 'learning_rate': 4.353333333333334e-05, 'epoch': 0.13}
# {'loss': 4.1209, 'grad_norm': 22.224212646484375, 'learning_rate': 3.6866666666666664e-05, 'epoch': 0.27}
# {'loss': 3.8706, 'grad_norm': 26.404348373413086, 'learning_rate': 3.02e-05, 'epoch': 0.4}
# {'loss': 3.656, 'grad_norm': 20.50556755065918, 'learning_rate': 2.3533333333333334e-05, 'epoch': 0.53}
# {'loss': 3.6378, 'grad_norm': 25.289775848388672, 'learning_rate': 1.6866666666666666e-05, 'epoch': 0.67}
# {'loss': 3.5207, 'grad_norm': 24.49275016784668, 'learning_rate': 1.02e-05, 'epoch': 0.8}
# {'loss': 3.4153, 'grad_norm': 21.04475212097168, 'learning_rate': 3.5333333333333335e-06, 'epoch': 0.93}
# {'train_runtime': 90.8124, 'train_samples_per_second': 66.07, 'train_steps_per_second': 8.259, 'train_loss': 3.8087288614908856, 'epoch': 1.0}
# 100% 750/750 [01:30<00:00,  8.26it/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/sarf_E2_seed_2026_work/cpt/checkpoint and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /content/drive/MyDrive/SARF_BANKING_NLP_PROJECT/src_04/arabert_pipeline.py:328: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `TimedTrainer.__init__`. Use `processing_class` instead.
#   super().__init__(*args, **kwargs)
# {'loss': 4.3654, 'grad_norm': 1.8038841485977173, 'learning_rate': 1.9994011976047905e-05, 'epoch': 0.01}
# {'loss': 4.1242, 'grad_norm': 1.9747388362884521, 'learning_rate': 1.952694610778443e-05, 'epoch': 0.48}
# {'loss': 3.4348, 'grad_norm': 2.1087677478790283, 'learning_rate': 1.9047904191616768e-05, 'epoch': 0.95}
#   5% 168/3340 [00:45<14:26,  3.66it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 49.37it/s]
#  26% 10/39 [00:00<00:00, 38.95it/s]
#  38% 15/39 [00:00<00:00, 37.90it/s]
#  49% 19/39 [00:00<00:00, 36.71it/s]
#  59% 23/39 [00:00<00:00, 32.43it/s]
#  69% 27/39 [00:00<00:00, 33.87it/s]
#  79% 31/39 [00:00<00:00, 34.47it/s]
#  90% 35/39 [00:00<00:00, 35.75it/s]
#
# {'eval_loss': 3.17201566696167, 'eval_macro_f1': 0.40621019806990893, 'eval_weighted_f1': 0.44525721137660107, 'eval_accuracy': 0.49227013832384053, 'eval_runtime': 1.1616, 'eval_samples_per_second': 1058.05, 'eval_steps_per_second': 33.575, 'epoch': 1.0}
#   5% 168/3340 [00:46<14:26,  3.66it/s]
# 100% 39/39 [00:01<00:00, 34.24it/s]
# {'loss': 2.7758, 'grad_norm': 2.6234290599823, 'learning_rate': 1.8568862275449104e-05, 'epoch': 1.43}
# {'loss': 2.2891, 'grad_norm': 2.9014859199523926, 'learning_rate': 1.8095808383233534e-05, 'epoch': 1.91}
#  10% 336/3340 [01:48<11:57,  4.19it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 47.75it/s]
#  26% 10/39 [00:00<00:00, 38.38it/s]
#  38% 15/39 [00:00<00:00, 37.85it/s]
#  49% 19/39 [00:00<00:00, 36.38it/s]
#  59% 23/39 [00:00<00:00, 33.30it/s]
#  69% 27/39 [00:00<00:00, 33.77it/s]
#  79% 31/39 [00:00<00:00, 34.60it/s]
#
# {'eval_loss': 2.3512749671936035, 'eval_macro_f1': 0.5654137436771826, 'eval_weighted_f1': 0.5979411712414046, 'eval_accuracy': 0.6224572823433686, 'eval_runtime': 1.1543, 'eval_samples_per_second': 1064.759, 'eval_steps_per_second': 33.788, 'epoch': 2.0}
#  10% 336/3340 [01:49<11:57,  4.19it/s]
# 100% 39/39 [00:01<00:00, 36.44it/s]
# {'loss': 1.8728, 'grad_norm': 2.567549705505371, 'learning_rate': 1.761676646706587e-05, 'epoch': 2.38}
# {'loss': 1.535, 'grad_norm': 3.1440792083740234, 'learning_rate': 1.7137724550898204e-05, 'epoch': 2.86}
#  15% 504/3340 [03:13<13:46,  3.43it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 45.72it/s]
#  26% 10/39 [00:00<00:00, 37.43it/s]
#  38% 15/39 [00:00<00:00, 38.60it/s]
#  49% 19/39 [00:00<00:00, 37.44it/s]
#  59% 23/39 [00:00<00:00, 33.81it/s]
#  69% 27/39 [00:00<00:00, 34.37it/s]
#  79% 31/39 [00:00<00:00, 35.56it/s]
#
# {'eval_loss': 1.914284586906433, 'eval_macro_f1': 0.6436050872249084, 'eval_weighted_f1': 0.6733446695036749, 'eval_accuracy': 0.6842961757526445, 'eval_runtime': 1.137, 'eval_samples_per_second': 1080.906, 'eval_steps_per_second': 34.301, 'epoch': 3.0}
#  15% 504/3340 [03:14<13:46,  3.43it/s]
# 100% 39/39 [00:01<00:00, 37.83it/s]
# {'loss': 1.2894, 'grad_norm': 2.452382802963257, 'learning_rate': 1.665868263473054e-05, 'epoch': 3.33}
# {'loss': 1.0875, 'grad_norm': 3.323370933532715, 'learning_rate': 1.6185628742514973e-05, 'epoch': 3.81}
#  20% 672/3340 [04:18<11:51,  3.75it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 45.44it/s]
#  26% 10/39 [00:00<00:00, 35.44it/s]
#  38% 15/39 [00:00<00:00, 35.86it/s]
#  49% 19/39 [00:00<00:00, 34.84it/s]
#  59% 23/39 [00:00<00:00, 31.37it/s]
#  69% 27/39 [00:00<00:00, 31.41it/s]
#  79% 31/39 [00:00<00:00, 31.54it/s]
#  90% 35/39 [00:01<00:00, 32.71it/s]
#
# {'eval_loss': 1.6941874027252197, 'eval_macro_f1': 0.668826107593537, 'eval_weighted_f1': 0.6954282430754498, 'eval_accuracy': 0.7021969080553295, 'eval_runtime': 1.2466, 'eval_samples_per_second': 985.892, 'eval_steps_per_second': 31.285, 'epoch': 4.0}
#  20% 672/3340 [04:19<11:51,  3.75it/s]
# 100% 39/39 [00:01<00:00, 31.46it/s]
# {'loss': 0.9459, 'grad_norm': 3.123016119003296, 'learning_rate': 1.5706586826347306e-05, 'epoch': 4.29}
# {'loss': 0.7914, 'grad_norm': 3.30049991607666, 'learning_rate': 1.5227544910179641e-05, 'epoch': 4.76}
#  25% 840/3340 [05:30<11:38,  3.58it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 50.38it/s]
#  31% 12/39 [00:00<00:00, 40.13it/s]
#  44% 17/39 [00:00<00:00, 37.71it/s]
#  54% 21/39 [00:00<00:00, 34.60it/s]
#  64% 25/39 [00:00<00:00, 32.93it/s]
#  74% 29/39 [00:00<00:00, 33.92it/s]
#  85% 33/39 [00:00<00:00, 35.44it/s]
#
# {'eval_loss': 1.594377040863037, 'eval_macro_f1': 0.6900441461698832, 'eval_weighted_f1': 0.7144120067531483, 'eval_accuracy': 0.7192839707078926, 'eval_runtime': 1.1553, 'eval_samples_per_second': 1063.771, 'eval_steps_per_second': 33.757, 'epoch': 5.0}
#  25% 840/3340 [05:31<11:38,  3.58it/s]
# 100% 39/39 [00:01<00:00, 34.40it/s]
# {'loss': 0.7303, 'grad_norm': 4.189413070678711, 'learning_rate': 1.4748502994011978e-05, 'epoch': 5.24}
# {'loss': 0.6224, 'grad_norm': 2.9259181022644043, 'learning_rate': 1.4269461077844313e-05, 'epoch': 5.72}
#  30% 1008/3340 [06:35<10:26,  3.72it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 47.09it/s]
#  26% 10/39 [00:00<00:00, 37.03it/s]
#  36% 14/39 [00:00<00:00, 36.75it/s]
#  46% 18/39 [00:00<00:00, 34.81it/s]
#  56% 22/39 [00:00<00:00, 30.89it/s]
#  67% 26/39 [00:00<00:00, 31.37it/s]
#  77% 30/39 [00:00<00:00, 32.16it/s]
#  87% 34/39 [00:01<00:00, 33.80it/s]
#
# {'eval_loss': 1.5382887125015259, 'eval_macro_f1': 0.7129456722327788, 'eval_weighted_f1': 0.7278949189482998, 'eval_accuracy': 0.7290480065093572, 'eval_runtime': 1.2217, 'eval_samples_per_second': 1006.002, 'eval_steps_per_second': 31.924, 'epoch': 6.0}
#  30% 1008/3340 [06:36<10:26,  3.72it/s]
# 100% 39/39 [00:01<00:00, 31.77it/s]
# {'loss': 0.5774, 'grad_norm': 3.4484663009643555, 'learning_rate': 1.3790419161676648e-05, 'epoch': 6.19}
# {'loss': 0.5054, 'grad_norm': 2.5312514305114746, 'learning_rate': 1.3311377245508983e-05, 'epoch': 6.67}
#  35% 1176/3340 [07:35<10:03,  3.58it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 47.35it/s]
#  26% 10/39 [00:00<00:00, 38.67it/s]
#  36% 14/39 [00:00<00:00, 39.17it/s]
#  46% 18/39 [00:00<00:00, 37.15it/s]
#  56% 22/39 [00:00<00:00, 32.93it/s]
#  67% 26/39 [00:00<00:00, 33.60it/s]
#  77% 30/39 [00:00<00:00, 33.97it/s]
#  90% 35/39 [00:00<00:00, 36.34it/s]
#
# {'eval_loss': 1.510810136795044, 'eval_macro_f1': 0.7161939664284326, 'eval_weighted_f1': 0.7304267144980235, 'eval_accuracy': 0.7306753458096013, 'eval_runtime': 1.1552, 'eval_samples_per_second': 1063.908, 'eval_steps_per_second': 33.761, 'epoch': 7.0}
#  35% 1176/3340 [07:36<10:03,  3.58it/s]
# 100% 39/39 [00:01<00:00, 34.50it/s]
# {'loss': 0.4837, 'grad_norm': 2.8736915588378906, 'learning_rate': 1.283233532934132e-05, 'epoch': 7.14}
# {'loss': 0.4273, 'grad_norm': 3.1094963550567627, 'learning_rate': 1.2353293413173652e-05, 'epoch': 7.62}
#  40% 1344/3340 [08:37<08:06,  4.10it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 49.88it/s]
#  28% 11/39 [00:00<00:00, 38.95it/s]
#  38% 15/39 [00:00<00:00, 37.75it/s]
#  49% 19/39 [00:00<00:00, 36.34it/s]
#  59% 23/39 [00:00<00:00, 33.10it/s]
#  69% 27/39 [00:00<00:00, 33.83it/s]
#  79% 31/39 [00:00<00:00, 34.40it/s]
#
# {'eval_loss': 1.4970667362213135, 'eval_macro_f1': 0.7195782537650738, 'eval_weighted_f1': 0.732475911218503, 'eval_accuracy': 0.7331163547599675, 'eval_runtime': 1.1487, 'eval_samples_per_second': 1069.913, 'eval_steps_per_second': 33.952, 'epoch': 8.0}
#  40% 1344/3340 [08:38<08:06,  4.10it/s]
# 100% 39/39 [00:01<00:00, 36.61it/s]
# {'loss': 0.3991, 'grad_norm': 1.7993407249450684, 'learning_rate': 1.1874251497005989e-05, 'epoch': 8.1}
# {'loss': 0.3622, 'grad_norm': 2.2983336448669434, 'learning_rate': 1.1395209580838324e-05, 'epoch': 8.57}
#  45% 1512/3340 [09:33<07:42,  3.95it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 48.73it/s]
#  26% 10/39 [00:00<00:00, 39.89it/s]
#  38% 15/39 [00:00<00:00, 38.86it/s]
#  49% 19/39 [00:00<00:00, 37.20it/s]
#  59% 23/39 [00:00<00:00, 33.26it/s]
#  69% 27/39 [00:00<00:00, 33.65it/s]
#  79% 31/39 [00:00<00:00, 34.21it/s]
#  90% 35/39 [00:00<00:00, 34.25it/s]
#
# {'eval_loss': 1.491255760192871, 'eval_macro_f1': 0.7230630659652604, 'eval_weighted_f1': 0.7360298538920188, 'eval_accuracy': 0.7363710333604556, 'eval_runtime': 1.1796, 'eval_samples_per_second': 1041.857, 'eval_steps_per_second': 33.061, 'epoch': 9.0}
#  45% 1512/3340 [09:35<07:42,  3.95it/s]
# 100% 39/39 [00:01<00:00, 32.76it/s]
# {'loss': 0.3399, 'grad_norm': 1.68027663230896, 'learning_rate': 1.091616766467066e-05, 'epoch': 9.05}
# {'loss': 0.3028, 'grad_norm': 2.560380220413208, 'learning_rate': 1.0437125748502994e-05, 'epoch': 9.52}
# {'loss': 0.312, 'grad_norm': 1.771244764328003, 'learning_rate': 9.95808383233533e-06, 'epoch': 10.0}
#  50% 1680/3340 [10:28<06:23,  4.33it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  15% 6/39 [00:00<00:00, 49.59it/s]
#  28% 11/39 [00:00<00:00, 40.07it/s]
#  41% 16/39 [00:00<00:00, 38.01it/s]
#  51% 20/39 [00:00<00:00, 37.02it/s]
#  62% 24/39 [00:00<00:00, 32.91it/s]
#  74% 29/39 [00:00<00:00, 34.86it/s]
#  87% 34/39 [00:00<00:00, 37.79it/s]
#
# {'eval_loss': 1.4822287559509277, 'eval_macro_f1': 0.7271440711482391, 'eval_weighted_f1': 0.7390919770055702, 'eval_accuracy': 0.7396257119609438, 'eval_runtime': 1.0943, 'eval_samples_per_second': 1123.123, 'eval_steps_per_second': 35.64, 'epoch': 10.0}
#  50% 1680/3340 [10:30<06:23,  4.33it/s]
# 100% 39/39 [00:01<00:00, 34.66it/s]
# {'loss': 0.2706, 'grad_norm': 3.5787711143493652, 'learning_rate': 9.479041916167665e-06, 'epoch': 10.48}
# {'loss': 0.273, 'grad_norm': 2.1313421726226807, 'learning_rate': 9e-06, 'epoch': 10.95}
#  55% 1848/3340 [11:26<05:59,  4.15it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 41.21it/s]
#  26% 10/39 [00:00<00:00, 35.57it/s]
#  38% 15/39 [00:00<00:00, 36.18it/s]
#  49% 19/39 [00:00<00:00, 35.97it/s]
#  59% 23/39 [00:00<00:00, 32.83it/s]
#  69% 27/39 [00:00<00:00, 33.23it/s]
#  79% 31/39 [00:00<00:00, 33.49it/s]
#  90% 35/39 [00:01<00:00, 34.30it/s]
#
# {'eval_loss': 1.5012341737747192, 'eval_macro_f1': 0.7238878158379212, 'eval_weighted_f1': 0.7352726331838941, 'eval_accuracy': 0.7355573637103336, 'eval_runtime': 1.2114, 'eval_samples_per_second': 1014.567, 'eval_steps_per_second': 32.195, 'epoch': 11.0}
#  55% 1848/3340 [11:27<05:59,  4.15it/s]
# 100% 39/39 [00:01<00:00, 32.43it/s]
# {'loss': 0.2389, 'grad_norm': 4.026262283325195, 'learning_rate': 8.520958083832335e-06, 'epoch': 11.43}
# {'loss': 0.2401, 'grad_norm': 2.9653284549713135, 'learning_rate': 8.041916167664672e-06, 'epoch': 11.91}
#  60% 2016/3340 [12:35<05:45,  3.83it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 45.85it/s]
#  26% 10/39 [00:00<00:00, 37.48it/s]
#  38% 15/39 [00:00<00:00, 37.02it/s]
#  49% 19/39 [00:00<00:00, 36.13it/s]
#  59% 23/39 [00:00<00:00, 31.73it/s]
#  69% 27/39 [00:00<00:00, 32.13it/s]
#  79% 31/39 [00:00<00:00, 33.06it/s]
#  90% 35/39 [00:01<00:00, 33.67it/s]
#
# {'eval_loss': 1.4938080310821533, 'eval_macro_f1': 0.72413552799652, 'eval_weighted_f1': 0.7364025114416525, 'eval_accuracy': 0.7363710333604556, 'eval_runtime': 1.2208, 'eval_samples_per_second': 1006.682, 'eval_steps_per_second': 31.945, 'epoch': 12.0}
#  60% 2016/3340 [12:36<05:45,  3.83it/s]
# 100% 39/39 [00:01<00:00, 31.97it/s]
# {'loss': 0.2124, 'grad_norm': 2.46909499168396, 'learning_rate': 7.562874251497007e-06, 'epoch': 12.38}
# {'loss': 0.2156, 'grad_norm': 2.483795166015625, 'learning_rate': 7.083832335329342e-06, 'epoch': 12.86}
#  65% 2184/3340 [13:44<05:25,  3.55it/s]
#   0% 0/39 [00:00<?, ?it/s]
#  13% 5/39 [00:00<00:00, 46.20it/s]
#  26% 10/39 [00:00<00:00, 37.46it/s]
#  36% 14/39 [00:00<00:00, 38.16it/s]
#  46% 18/39 [00:00<00:00, 35.70it/s]
#  56% 22/39 [00:00<00:00, 31.17it/s]
#  67% 26/39 [00:00<00:00, 31.72it/s]
#  77% 30/39 [00:00<00:00, 32.69it/s]
#  90% 35/39 [00:01<00:00, 34.95it/s]
#
# {'eval_loss': 1.5139094591140747, 'eval_macro_f1': 0.722141358880256, 'eval_weighted_f1': 0.7336491907307998, 'eval_accuracy': 0.7339300244100895, 'eval_runtime': 1.2155, 'eval_samples_per_second': 1011.072, 'eval_steps_per_second': 32.084, 'epoch': 13.0}
#  65% 2184/3340 [13:45<05:25,  3.55it/s]
# 100% 39/39 [00:01<00:00, 32.98it/s]
# {'train_runtime': 843.0734, 'train_samples_per_second': 254.592, 'train_steps_per_second': 3.962, 'train_loss': 0.9792161588267092, 'epoch': 13.0}
#  65% 2184/3340 [14:03<07:26,  2.59it/s]
# 100% 39/39 [00:01<00:00, 37.29it/s]
# {
#   "run_id": "E2_seed_2026",
#   "owner": "A",
#   "model_family": "AraBERTv2-base",
#   "condition": "E2",
#   "run_type": "official",
#   "seed": 2026,
#   "base_checkpoint": "aubmindlab/bert-base-arabertv2",
#   "config_id": "arabert_config",
#   "train_split": "msa_train_v1",
#   "validation_split": "msa_val_v1",
#   "train_rows": 10732,
#   "validation_rows": 1229,
#   "num_labels": 77,
#   "cpt_corpus_files": [
#     "general_6k_final_v2.csv"
#   ],
#   "cpt_details": {
#     "condition": "E2",
#     "corpus_files": [
#       "general_6k_final_v2.csv"
#     ],
#     "corpus_file_rows": {
#       "general_6k_final_v2.csv": 6000
#     },
#     "total_rows": 6000,
#     "text_column_only": true,
#     "objective": "masked_language_modeling",
#     "epochs": 1,
#     "training_loss": 3.8087288614908856
#   },
#   "checkpoint_selection_metric": "macro_f1 on MSA validation",
#   "best_epoch": 10.0,
#   "metrics": {
#     "macro_f1": 0.7271440711482391,
#     "weighted_f1": 0.7390919770055702,
#     "accuracy": 0.7396257119609438
#   },
#   "prediction_file": "validation_predictions.csv",
#   "per_class_file": "per_class_metrics.csv",
#   "confusion_matrix_file": "confusion_matrix.csv",
#   "runtime_seconds": {
#     "loading_and_tokenization_seconds": 10.144703059000221,
#     "cpt_seconds": 106.46474134600021,
#     "fine_tuning_seconds": 593.4796687569983,
#     "validation_during_training_seconds": 15.362270713000271,
#     "checkpoint_saving_during_training_seconds": 234.8360040800012,
#     "final_validation_export_reload_seconds": 4.946615384999859,
#     "validation_and_checkpoint_saving_seconds": 255.14489017800133,
#     "total_runtime_seconds": 965.2340033400001,
#     "total_runtime_definition": "Sum of measured loading/tokenization, CPT when applicable, fine-tuning, validation, checkpoint saving, export, and reload steps."
#   },
#   "truncation_audit": {
#     "max_length": 128,
#     "train_truncation_rate": 0.0,
#     "validation_truncation_rate": 0.0,
#     "train_max_untruncated_length": 111,
#     "validation_max_untruncated_length": 103
#   },
#   "checks": {
#     "labels_77_verified": true,
#     "logits_shape_verified": [
#       1229,
#       77
#     ],
#     "predictions_not_single_label": true,
#     "best_checkpoint_selected_by_macro_f1": true,
#     "checkpoint_reload_passed": true,
#     "approved_msa_inputs_only": true,
#     "zero_truncation_at_frozen_max_length": true,
#     "fresh_base_checkpoint_used": true
#   },
#   "saudi_test_accessed": false,
#   "status": "completed"
# }
